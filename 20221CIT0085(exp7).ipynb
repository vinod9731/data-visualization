# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cars_data=pd.read_csv("/content/Toyota.csv",index_col=0,na_values=['??','????'])

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 13500 to 6950
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        1436 non-null   int64
#  1   KM         1436 non-null   int64
#  2   FuelType   1436 non-null   object
#  3   HP         1436 non-null   int64
#  4   MetColor   1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   CC         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Weight     1436 non-null   int64
# dtypes: int64(8), object(1)
# memory usage: 112.2+ KB

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5     12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1423   7950  80.0  35821.0   Petrol   86.0       0.0          1  1300      3
# 1424   7750  73.0  34717.0   Petrol   86.0       0.0          0  1300      3
# 1429   8950  78.0  24000.0   Petrol   86.0       1.0          1  1300      5
# 1430   8450  80.0  23000.0   Petrol   86.0       0.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 3       1165
# 4       1170
# 5       1170
# ...      ...
# 1423    1015
# 1424    1015
# 1429    1065
# 1430    1015
# 1435    1114
#
# [1096 rows x 10 columns]

# %%
plt.scatter(cars_data['Age'],cars_data['Price'],c='red')
plt.gca().set_facecolor('black')
plt.title('Scatter plot of Price vs Age')
plt.xlabel('Age(month)')
plt.ylabel('Price(Euros)')
plt.show()

# %%
plt.hist(cars_data['KM'])
# Out:
# (array([ 92., 239., 331., 222., 111.,  51.,  25.,  13.,  10.,   2.]),
#  array([1.000000e+00, 2.430090e+04, 4.860080e+04, 7.290070e+04,
#         9.720060e+04, 1.215005e+05, 1.458004e+05, 1.701003e+05,
#         1.944002e+05, 2.187001e+05, 2.430000e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(cars_data["KM"],color="Green",edgecolor='white',bins=30)
plt.title('Histogram of KM')
plt.xlabel('Kilometer')
plt.ylabel('Frequency')
plt.show()

# %%
counts=[979,120,2]
fueltype=('Petrol','Diesel','CNG')
index=np.arange(len(fueltype))

# %%
plt.bar(index,counts,color=['red','blue','cyan'])
plt.title('Bar plot of fuel type')
plt.xlabel('Fuel Types')
plt.ylabel('Frequency')
plt.xticks(index,fueltype,rotation=60)
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ***OPERATIONS ON BTC DATASET        Bitcoin daily (Jul 2010-Mar 2024) ***
#
# ---
#
#
#
# ---

# %%
btc=pd.read_csv("/content/btc.csv",index_col=0)

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4994 entries, 2010-07-18 to 2024-03-19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    4994 non-null   float64
#  1   High    4994 non-null   float64
#  2   Low     4994 non-null   float64
#  3   Close   4994 non-null   float64
#  4   Volume  4988 non-null   float64
# dtypes: float64(5)
# memory usage: 234.1+ KB

# %%
btc.dropna(axis=0,inplace=True)
btc
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2010-07-18      0.0      0.1      0.1      0.1  8.000000e+01
# 2010-07-19      0.1      0.1      0.1      0.1  5.700000e+02
# 2010-07-20      0.1      0.1      0.1      0.1  2.600000e+02
# 2010-07-21      0.1      0.1      0.1      0.1  5.800000e+02
# 2010-07-22      0.1      0.1      0.1      0.1  2.160000e+03
# ...             ...      ...      ...      ...           ...
# 2024-03-15  71387.9  72357.1  65630.7  69403.8  7.832045e+10
# 2024-03-16  69392.5  70046.3  64801.4  65315.1  4.684220e+10
# 2024-03-17  65316.3  68845.7  64545.3  68390.6  4.471686e+10
# 2024-03-18  68371.3  68897.1  66594.2  67548.6  4.926158e+10
# 2024-03-19  67556.1  68106.9  61536.2  61912.8  7.421584e+10
#
# [4988 rows x 5 columns]

# %%
plt.scatter(btc['Low'],btc['High'],c='yellow')
plt.gca().set_facecolor('cyan')
plt.title('Scatter plot of Low vs High')
plt.xlabel('Low')
plt.ylabel('High')
plt.show()

# %%
plt.hist(btc['Close'])
# Out:
# (array([3067.,  663.,  265.,  264.,  185.,  230.,  149.,   90.,   59.,
#           16.]),
#  array([1.000000e-01, 7.308440e+03, 1.461678e+04, 2.192512e+04,
#         2.923346e+04, 3.654180e+04, 4.385014e+04, 5.115848e+04,
#         5.846682e+04, 6.577516e+04, 7.308350e+04]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(btc["Close"],color="Green",edgecolor='white',bins=50)
plt.title('Histogram of Close')

plt.show()
