# %%
import pandas as pd

meteorites = pd.read_csv('Meteorite_Landings_20240305.csv',nrows=5)
meteorites
# Out:
#        name   id nametype     recclass  mass (g)  fall  year    reclat  \
# 0    Aachen    1    Valid           L5        21  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6       720  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4    107000  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6       780  Fell  1902 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import pandas as pd

meteorites = pd.read_csv('Meteorite_Landings_20240305.csv')
meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
meteorites.name
# Out:
# 0            Aachen
# 1            Aarhus
# 2              Abee
# 3          Acapulco
# 4           Achiras
#             ...
# 45711    Zillah 002
# 45712        Zinder
# 45713          Zlin
# 45714     Zubkovsky
# 45715    Zulu Queen
# Name: name, Length: 45716, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=45716, step=1)

# %%
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4ga-9sfh.json',
    params={'$limit':50_000}
)

if response.ok:
    payload = response.json()
else:
    print(f'request was not successful and returned: {response.status_code}')
    payload = None
# Out:
# request was not successful and returned: 404

# %%
import pandas as pd

df = pd.DataFrame(payload)
df.head(3)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
meteorites.shape
# Out:
# (45716, 10)

# %%
meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year           float64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteorites.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
meteorites.tail()
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# 45711  1990.0  29.03700   17.01850       (29.037, 17.0185)
# 45712  1999.0  13.78333    8.96667     (13.78333, 8.96667)
# 45713  1939.0  49.25000   17.66667       (49.25, 17.66667)
# 45714  2003.0  49.78917   41.50460     (49.78917, 41.5046)
# 45715  1976.0  33.98333 -115.68333  (33.98333, -115.68333)

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
meteorites[['name','mass (g)']]
# Out:
#              name  mass (g)
# 0          Aachen      21.0
# 1          Aarhus     720.0
# 2            Abee  107000.0
# 3        Acapulco    1914.0
# 4         Achiras     780.0
# ...           ...       ...
# 45711  Zillah 002     172.0
# 45712      Zinder      46.0
# 45713        Zlin       3.3
# 45714   Zubkovsky    2167.0
# 45715  Zulu Queen     200.0
#
# [45716 rows x 2 columns]

# %%
meteorites[100:104]
# Out:
#               name     id nametype       recclass  mass (g)  fall    year  \
# 100         Benton   5026    Valid            LL6    2840.0  Fell  1949.0
# 101         Berduc  48975    Valid             L6     270.0  Fell  2008.0
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell  1924.0
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell  1811.0
#
#        reclat   reclong          GeoLocation
# 100  45.95000 -67.55000      (45.95, -67.55)
# 101 -31.91000 -58.32833  (-31.91, -58.32833)
# 102  11.65000  -3.65000       (11.65, -3.65)
# 103  41.68333  -3.80000     (41.68333, -3.8)

# %%
meteorites.iloc[100:104,[0,2,4,6]]
# Out:
#               name nametype  mass (g)    year
# 100         Benton    Valid    2840.0  1949.0
# 101         Berduc    Valid     270.0  2008.0
# 102         Béréba    Valid   18000.0  1924.0
# 103  Berlanguillas    Valid    1440.0  1811.0

# %%
meteorites.loc[100:104,'mass (g)':'year']
# Out:
#      mass (g)  fall    year
# 100    2840.0  Fell  1949.0
# 101     270.0  Fell  2008.0
# 102   18000.0  Fell  1924.0
# 103    1440.0  Fell  1811.0
# 104     960.0  Fell  2004.0

# %%
(meteorites['mass (g)']>58)&(meteorites.fall == 'Found')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool
