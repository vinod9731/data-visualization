# %%
import pandas as pd

# %%
df = pd.read_csv('/content/train.csv')

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
age_mean_value=df['Age'].mean()
df['Age']=df['Age'].fillna(age_mean_value)

# %%
df.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 873                       Vander Cruyssen, Mr. Victor    male  47.0      0
# 874             Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                  Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                     Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                              Petroff, Mr. Nedelio    male  19.0      0
# 878                                Laleff, Mr. Kristo    male   NaN      0
# 879     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880      Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                Markun, Mr. Johann    male  33.0      0
# 882                      Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                     Banfield, Mr. Frederick James    male  28.0      0
# 884                            Sutehall, Mr. Henry Jr    male  25.0      0
# 885              Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                             Montvila, Rev. Juozas    male  27.0      0
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 888          Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                             Behr, Mr. Karl Howell    male  26.0      0
# 890                               Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare        Cabin Embarked
# 871      1             11751  52.5542          D35        S
# 872      0               695   5.0000  B51 B53 B55        S
# 873      0            345765   9.0000          NaN        S
# 874      0         P/PP 3381  24.0000          NaN        C
# 875      0              2667   7.2250          NaN        C
# 876      0              7534   9.8458          NaN        S
# 877      0            349212   7.8958          NaN        S
# 878      0            349217   7.8958          NaN        S
# 879      1             11767  83.1583          C50        C
# 880      1            230433  26.0000          NaN        S
# 881      0            349257   7.8958          NaN        S
# 882      0              7552  10.5167          NaN        S
# 883      0  C.A./SOTON 34068  10.5000          NaN        S
# 884      0   SOTON/OQ 392076   7.0500          NaN        S
# 885      5            382652  29.1250          NaN        Q
# 886      0            211536  13.0000          NaN        S
# 887      0            112053  30.0000          B42        S
# 888      2        W./C. 6607  23.4500          NaN        S
# 889      0            111369  30.0000         C148        C
# 890      0            370376   7.7500          NaN        Q

# %%
 df.drop("Cabin",axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
filtered_age = df[df.Age>40]
filtered_age

sorted_passengers= df.sort_values('Name',ascending=True,kind = 'heapsort')

sorted_passengers.head(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 845                             Abbing, Mr. Anthony    male  42.0      0
# 746                     Abbott, Mr. Rossmore Edward    male  16.0      1
# 279                Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 308                             Abelson, Mr. Samuel    male  30.0      1
# 874           Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 365                  Adahl, Mr. Mauritz Nils Martin    male  30.0      0
# 401                                 Adams, Mr. John    male  26.0      0
# 40   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 855                      Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 207                     Albimona, Mr. Nassef Cassem    male  26.0      0
#
#      Parch     Ticket     Fare Embarked
# 845      0  C.A. 5547   7.5500        S
# 746      1  C.A. 2673  20.2500        S
# 279      1  C.A. 2673  20.2500        S
# 308      0  P/PP 3381  24.0000        C
# 874      0  P/PP 3381  24.0000        C
# 365      0     C 7076   7.2500        S
# 401      0     341826   8.0500        S
# 40       0       7546   9.4750        S
# 855      1     392091   9.3500        S
# 207      0       2699  18.7875        C

# %%
merged_df=pd.merge(df.head(2),df.tail(2),how='outer',indicator=True)
merged_df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2          890         1       1
# 3          891         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Behr, Mr. Karl Howell    male  26.0      0
# 3                                Dooley, Mr. Patrick    male  32.0      0
#
#    Parch     Ticket     Fare Embarked      _merge
# 0      0  A/5 21171   7.2500        S   left_only
# 1      0   PC 17599  71.2833        C   left_only
# 2      0     111369  30.0000        C  right_only
# 3      0     370376   7.7500        Q  right_only

# %%
group_df = df.groupby('Name')

for key,item in group_df:
  print(group_df.get_group(key),"\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#      Parch      Ticket  Fare Cabin Embarked
# 671      0  F.C. 12750  52.0   B71        S
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 549          550         1       2  Davies, Master. John Morgan Jr  male  8.0
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked
# 549      1      1  C.A. 33112  36.75   NaN        S
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 565          566         0       3  Davies, Mr. Alfred J  male  24.0      2
#
#      Parch     Ticket   Fare Cabin Embarked
# 565      0  A/4 48871  24.15   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 385          386         0       2  Davies, Mr. Charles Henry  male  18.0
#
#      SibSp  Parch        Ticket  Fare Cabin Embarked
# 385      0      0  S.O.C. 14879  73.5   NaN        S
#
#
#      PassengerId  Survived  Pclass               Name     Sex   Age  SibSp  \
# 635          636         1       2  Davis, Miss. Mary  female  28.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 635      0  237668  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                                       Name  \
# 347          348         1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 347  female  NaN      1      0  386525  16.1   NaN        S
#
#
#      PassengerId  Survived  Pclass                        Name   Sex  Age  \
# 788          789         1       3  Dean, Master. Bertram Vere  male  1.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked
# 788      1      2  C.A. 2315  20.575   NaN        S
#
#
#     PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 93           94         0       3  Dean, Mr. Bertram Frank  male  26.0      1
#
#     Parch     Ticket    Fare Cabin Embarked
# 93      2  C.A. 2315  20.575   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 335          336         0       3  Denkoff, Mr. Mitto  male  NaN      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 335      0  349225  7.8958   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 320          321         0       3  Dennis, Mr. Samuel  male  22.0      0
#
#      Parch     Ticket  Fare Cabin Embarked
# 320      0  A/5 21172  7.25   NaN        S
#
#
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 44           45         1       3  Devaney, Miss. Margaret Delia  female
#
#      Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 44  19.0      0      0  330958  7.8792   NaN        Q
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 690          691         1       1  Dick, Mr. Albert Adrian  male  31.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 690      1      0  17474  57.0   B20        S
#
#
#      PassengerId  Survived  Pclass                                       Name  \
# 781          782         1       1  Dick, Mrs. Albert Adrian (Vera Gillespie)
#
#         Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 781  female  17.0      1      0  17474  57.0   B20        S
#
#
#      PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  \
# 349          350         0       3  Dimic, Mr. Jovan  male  42.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 349      0  315088  8.6625   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 445          446         1       1  Dodge, Master. Washington  male  4.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 445      0      2  33638  81.8583   A34        S
#
#
#      PassengerId  Survived  Pclass                 Name   Sex  Age  SibSp  \
# 568          569         0       3  Doharr, Mr. Tannous  male  NaN      0
#
#      Parch Ticket    Fare Cabin Embarked
# 568      0   2686  7.2292   NaN        C
#
#
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 651          652         1       2  Doling, Miss. Elsie  female  18.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 651      1  231919  23.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                                  Name  \
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
#
#        Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 98  female  34.0      0      1  231919  23.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 283          284         1       3  Dorking, Mr. Edward Arthur  male  19.0
#
#      SibSp  Parch      Ticket  Fare Cabin Embarked
# 283      0      0  A/5. 10482  8.05   NaN        S
#
#
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 544          545         0       1  Douglas, Mr. Walter Donald  male  50.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 544      1      0  PC 17761  106.425   C86        C
#
#
#     PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 79           80         1       3  Dowdell, Miss. Elizabeth  female  30.0
#
#     SibSp  Parch  Ticket    Fare Cabin Embarked
# 79      0      0  364516  12.475   NaN        S
#
#
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 582          583         0       2  Downton, Mr. William James  male  54.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 582      0      0  28403  26.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 130          131         0       3  Drazenoic, Mr. Jozef  male  33.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 130      0  349241  7.8958   NaN        C
#
#
#      PassengerId  Survived  Pclass  \
# 416          417         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 416  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 416      1  28220  32.5   NaN        S
#
#
#      PassengerId  Survived  Pclass              Name   Sex   Age  SibSp  \
# 280          281         0       3  Duane, Mr. Frank  male  65.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 280      0  336439  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass  \
# 556          557         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 556      0  11755  39.6   A16        C
#
#
#      PassengerId  Survived  Pclass  \
# 599          600         1       1
#
#                                              Name   Sex   Age  SibSp  Parch  \
# 599  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")  male  49.0      1      0
#
#        Ticket     Fare Cabin Embarked
# 599  PC 17485  56.9292   A20        C
#
#
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 866          867         1       2  Duran y More, Miss. Asuncion  female
#
#       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 866  27.0      1      0  SC/PARIS 2149  13.8583   NaN        C
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 675          676         0       3  Edvardsson, Mr. Gustaf Hjalmar  male
#
#       Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 675  18.0      0      0  349912  7.775   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 658          659         0       2  Eitemiller, Mr. George Floyd  male  23.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 658      0      0  29751  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 764          765         0       3  Eklund, Mr. Hans Linus  male  16.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 764      0  347074  7.775   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 129          130         0       3  Ekstrom, Mr. Johan  male  45.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 129      0  347061  6.975   NaN        S
#
#
#      PassengerId  Survived  Pclass             Name   Sex  Age  SibSp  Parch  \
# 773          774         0       3  Elias, Mr. Dibo  male  NaN      0      0
#
#     Ticket   Fare Cabin Embarked
# 773   2674  7.225   NaN        C
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 532          533         0       3  Elias, Mr. Joseph Jr  male  17.0      1
#
#      Parch Ticket    Fare Cabin Embarked
# 532      1   2690  7.2292   NaN        C
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 352          353         0       3  Elias, Mr. Tannous  male  15.0      1
#
#      Parch Ticket    Fare Cabin Embarked
# 352      1   2695  7.2292   NaN        C
#
#
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 592          593         0       3  Elsbury, Mr. William James  male  47.0
#
#      SibSp  Parch    Ticket  Fare Cabin Embarked
# 592      0      0  A/5 3902  7.25   NaN        S
#
#
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 777          778         1       3  Emanuel, Miss. Virginia Ethel  female
#
#      Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 777  5.0      0      0  364516  12.475   NaN        S
#
#
#     PassengerId  Survived  Pclass                     Name   Sex  Age  SibSp  \
# 26           27         0       3  Emir, Mr. Farred Chehab  male  NaN      0
#
#     Parch Ticket   Fare Cabin Embarked
# 26      0   2631  7.225   NaN        C
#
#
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 716          717         1       1  Endres, Miss. Caroline Louise  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 716  38.0      0      0  PC 17757  227.525   C45        C
#
#
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 496          497         1       1  Eustis, Miss. Elizabeth Mussey  female
#
#       Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 496  54.0      1      0  36947  78.2667   D20        C
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 228          229         0       2  Fahlstrom, Mr. Arne Jonas  male  18.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 228      0      0  236171  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 525          526         0       3  Farrell, Mr. James  male  40.5      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 525      0  367232  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 527          528         0       1  Farthing, Mr. John  male  NaN      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 527      0  PC 17483  221.7792   C95        S
#
#
#     PassengerId  Survived  Pclass  \
# 53           54         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
#
#     Parch Ticket  Fare Cabin Embarked
# 53      0   2926  26.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 688          689         0       3  Fischer, Mr. Eberhard Thelander  male
#
#       Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 688  18.0      0      0  350036  7.7958   NaN        S
#
#
#      PassengerId  Survived  Pclass                     Name     Sex  Age  \
# 306          307         1       1  Fleming, Miss. Margaret  female  NaN
#
#      SibSp  Parch Ticket      Fare Cabin Embarked
# 306      0      0  17421  110.8833   NaN        C
#
#
#      PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 428          429         0       3  Flynn, Mr. James  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked
# 428  364851  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass             Name   Sex  Age  SibSp  Parch  \
# 825          826         0       3  Flynn, Mr. John  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked
# 825  368323  6.95   NaN        Q
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 572          573         1       1  Flynn, Mr. John Irwin ("Irving")  male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 572  36.0      0      0  PC 17474  26.3875   E25        S
#
#
#      PassengerId  Survived  Pclass             Name   Sex  Age  SibSp  Parch  \
# 643          644         1       3  Foo, Mr. Choong  male  NaN      0      0
#
#     Ticket     Fare Cabin Embarked
# 643   1601  56.4958   NaN        S
#
#
#      PassengerId  Survived  Pclass                                  Name  \
# 436          437         0       3  Ford, Miss. Doolina Margaret "Daisy"
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 436  female  21.0      2      2  W./C. 6608  34.375   NaN        S
#
#
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 147          148         0       3  Ford, Miss. Robina Maggie "Ruby"  female
#
#      Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 147  9.0      2      2  W./C. 6608  34.375   NaN        S
#
#
#     PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 86           87         0       3  Ford, Mr. William Neal  male  16.0      1
#
#     Parch      Ticket    Fare Cabin Embarked
# 86      3  W./C. 6608  34.375   NaN        S
#
#
#      PassengerId  Survived  Pclass                                     Name  \
# 736          737         0       3  Ford, Mrs. Edward (Margaret Ann Watson)
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 736  female  48.0      1      3  W./C. 6608  34.375   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 452          453         0       1  Foreman, Mr. Benjamin Laventall  male
#
#       Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 452  30.0      0      0  113051  27.75  C111        C
#
#
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 341          342         1       1  Fortune, Miss. Alice Elizabeth  female
#
#       Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 341  24.0      3      2  19950  263.0  C23 C25 C27        S
#
#
#     PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 88           89         1       1  Fortune, Miss. Mabel Helen  female  23.0
#
#     SibSp  Parch Ticket   Fare        Cabin Embarked
# 88      3      2  19950  263.0  C23 C25 C27        S
#
#
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 27           28         0       1  Fortune, Mr. Charles Alexander  male  19.0
#
#     SibSp  Parch Ticket   Fare        Cabin Embarked
# 27      3      2  19950  263.0  C23 C25 C27        S
#
#
#      PassengerId  Survived  Pclass               Name   Sex   Age  SibSp  \
# 438          439         0       1  Fortune, Mr. Mark  male  64.0      1
#
#      Parch Ticket   Fare        Cabin Embarked
# 438      4  19950  263.0  C23 C25 C27        S
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 344          345         0       2  Fox, Mr. Stanley Hubert  male  36.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 344      0      0  229236  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 309          310         1       1  Francatelli, Miss. Laura Mabel  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 309  30.0      0      0  PC 17485  56.9292   E36        C
#
#
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 660          661         1       1  Frauenthal, Dr. Henry William  male  50.0
#
#      SibSp  Parch    Ticket    Fare Cabin Embarked
# 660      2      0  PC 17611  133.65   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 334          335         1       1
#
#                                                   Name     Sex  Age  SibSp  \
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  female  NaN      1
#
#      Parch    Ticket    Fare Cabin Embarked
# 334      0  PC 17611  133.65   NaN        S
#
#
#      PassengerId  Survived  Pclass                                Name  \
# 539          540         1       1  Frolicher, Miss. Hedwig Margaritha
#
#         Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 539  female  22.0      0      2  13568  49.5   B39        C
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 587          588         1       1  Frolicher-Stehli, Mr. Maxmillian  male
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 587  60.0      1      1  13567  79.2   B41        C
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 481  NaN      0      0  239854   0.0   NaN        S
#
#
#      PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 815          816         0       1  Fry, Mr. Richard  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked
# 815  112058   0.0  B102        S
#
#
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 357          358         0       2  Funk, Miss. Annie Clemmer  female  38.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 357      0      0  237671  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 137          138         0       1  Futrelle, Mr. Jacques Heath  male  37.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 137      1      0  113803  53.1  C123        S
#
#
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#    Ticket  Fare Cabin Embarked
# 3  113803  53.1  C123        S
#
#
#     PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 20           21         0       2  Fynney, Mr. Joseph J  male  35.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 20      0  239865  26.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 405          406         0       2  Gale, Mr. Shadrach  male  34.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 405      0  28664  21.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 703          704         0       3  Gallagher, Mr. Martin  male  25.0      0
#
#      Parch Ticket    Fare Cabin Embarked
# 703      0  36864  7.7417   NaN        Q
#
#
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 760          761         0       3  Garfirth, Mr. John  male  NaN      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 760      0  358585  14.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 576          577         1       2  Garside, Miss. Ethel  female  34.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 576      0  243880  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 791          792         0       2  Gaskell, Mr. Alfred  male  16.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 791      0  239865  26.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 619          620         0       2  Gavey, Mr. Lawrence  male  26.0      0
#
#      Parch Ticket  Fare Cabin Embarked
# 619      0  31028  10.5   NaN        S
#
#
#      PassengerId  Survived  Pclass               Name   Sex   Age  SibSp  \
# 462          463         0       1  Gee, Mr. Arthur H  male  47.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 462      0  111320  38.5   E63        S
#
#
#      PassengerId  Survived  Pclass                    Name   Sex  Age  SibSp  \
# 420          421         0       3  Gheorgheff, Mr. Stanio  male  NaN      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 420      0  349254  7.8958   NaN        C
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 139          140         0       1  Giglio, Mr. Victor  male  24.0      0
#
#      Parch    Ticket  Fare Cabin Embarked
# 139      0  PC 17593  79.2   B86        C
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 861          862         0       2  Giles, Mr. Frederick Edward  male  21.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 861      1      0  28134  11.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 588          589         0       3  Gilinski, Mr. Eliezer  male  22.0      0
#
#      Parch Ticket  Fare Cabin Embarked
# 588      0  14973  8.05   NaN        S
#
#
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 864          865         0       2  Gill, Mr. John William  male  24.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 864      0  233866  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 722          723         0       2  Gillespie, Mr. William Henry  male  34.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 722      0      0  12233  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 156          157         1       3  Gilnagh, Miss. Katherine "Katie"  female
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 156  16.0      0      0  35851  7.7333   NaN        Q
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 213          214         0       2  Givard, Mr. Hans Kristensen  male  30.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 213      0      0  250646  13.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                      Name     Sex  Age  \
# 32           33         1       3  Glynn, Miss. Mary Agatha  female  NaN
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 32      0      0  335677  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 453          454         1       1  Goldenberg, Mr. Samuel L  male  49.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 453      1      0  17453  89.1042   C92        C
#
#
#      PassengerId  Survived  Pclass  \
# 849          850         1       1
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1      0
#
#     Ticket     Fare Cabin Embarked
# 849  17453  89.1042   C92        C
#
#
#     PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 96           97         0       1  Goldschmidt, Mr. George B  male  71.0
#
#     SibSp  Parch    Ticket     Fare Cabin Embarked
# 96      0      0  PC 17754  34.6542    A5        C
#
#
#      PassengerId  Survived  Pclass  \
# 165          166         1       3
#
#                                                 Name   Sex  Age  SibSp  Parch  \
# 165  Goldsmith, Master. Frank John William "Frankie"  male  9.0      0      2
#
#      Ticket    Fare Cabin Embarked
# 165  363291  20.525   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 548          549         0       3  Goldsmith, Mr. Frank John  male  33.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 548      1      1  363291  20.525   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 328          329         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 328  Goldsmith, Mrs. Frank John (Emily Alice Brown)  female  31.0      1
#
#      Parch  Ticket    Fare Cabin Embarked
# 328      1  363291  20.525   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 465          466         0       3  Goncalves, Mr. Manuel Estanslas  male
#
#       Age  SibSp  Parch              Ticket  Fare Cabin Embarked
# 465  38.0      0      0  SOTON/O.Q. 3101306  7.05   NaN        S
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  Age  \
# 480          481         0       3  Goodwin, Master. Harold Victor  male  9.0
#
#      SibSp  Parch   Ticket  Fare Cabin Embarked
# 480      5      2  CA 2144  46.9   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 386          387         0       3  Goodwin, Master. Sidney Leonard  male
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 386  1.0      5      2  CA 2144  46.9   NaN        S
#
#
#     PassengerId  Survived  Pclass                                Name   Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick  male
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9   NaN        S
#
#
#     PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 71           72         0       3  Goodwin, Miss. Lillian Amy  female  16.0
#
#     SibSp  Parch   Ticket  Fare Cabin Embarked
# 71      5      2  CA 2144  46.9   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 683          684         0       3  Goodwin, Mr. Charles Edward  male  14.0
#
#      SibSp  Parch   Ticket  Fare Cabin Embarked
# 683      5      2  CA 2144  46.9   NaN        S
#
#
#      PassengerId  Survived  Pclass                                     Name  \
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 678  female  43.0      1      6  CA 2144  46.9   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 887          888         1       1  Graham, Miss. Margaret Edith  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 887  19.0      0      0  112053  30.0   B42        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 332          333         0       1  Graham, Mr. George Edward  male  38.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked
# 332      0      1  PC 17582  153.4625   C91        S
#
#
#      PassengerId  Survived  Pclass  \
# 268          269         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 268  Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 268      1  PC 17582  153.4625  C125        S
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 222          223         0       3  Green, Mr. George Henry  male  51.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 222      0      0  21440  8.05   NaN        S
#
#
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 714          715         0       2  Greenberg, Mr. Samuel  male  52.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 714      0  250647  13.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 97           98         1       1  Greenfield, Mr. William Bertram  male
#
#      Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 97  23.0      0      1  PC 17759  63.3583  D10 D12        C
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 769          770         0       3  Gronnestad, Mr. Daniel Danielsen  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 769  32.0      0      0   8471  8.3625   NaN        S
#
#
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 789          790         0       1  Guggenheim, Mr. Benjamin  male  46.0
#
#      SibSp  Parch    Ticket  Fare    Cabin Embarked
# 789      0      0  PC 17593  79.2  B82 B84        C
#
#
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 876          877         0       3  Gustafsson, Mr. Alfred Ossian  male  20.0
#
#      SibSp  Parch Ticket    Fare Cabin Embarked
# 876      0      0   7534  9.8458   NaN        S
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 104          105         0       3  Gustafsson, Mr. Anders Vilhelm  male
#
#       Age  SibSp  Parch   Ticket   Fare Cabin Embarked
# 104  37.0      2      0  3101276  7.925   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 392          393         0       3  Gustafsson, Mr. Johan Birger  male  28.0
#
#      SibSp  Parch   Ticket   Fare Cabin Embarked
# 392      2      0  3101277  7.925   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 379          380         0       3  Gustafsson, Mr. Karl Gideon  male  19.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 379      0      0  347069  7.775   NaN        S
#
#
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 293          294         0       3  Haas, Miss. Aloisia  female  24.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 293      0  349236  8.85   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 451          452         0       3  Hagland, Mr. Ingvald Olai Olsen  male
#
#      Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 451  NaN      1      0  65303  19.9667   NaN        S
#
#
#      PassengerId  Survived  Pclass                                  Name  \
# 490          491         0       3  Hagland, Mr. Konrad Mathias Reiersen
#
#       Sex  Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 490  male  NaN      1      0  65304  19.9667   NaN        S
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 403          404         0       3  Hakkarainen, Mr. Pekka Pietari  male
#
#       Age  SibSp  Parch            Ticket   Fare Cabin Embarked
# 403  28.0      1      0  STON/O2. 3101279  15.85   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 142          143         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.0      1
#
#      Parch            Ticket   Fare Cabin Embarked
# 142      0  STON/O2. 3101279  15.85   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 178          179         0       2  Hale, Mr. Reginald  male  30.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 178      0  250653  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 755          756         1       2  Hamalainen, Master. Viljo  male  0.67
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 755      1      1  250649  14.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 247          248         1       2  Hamalainen, Mrs. William (Anna)  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 247  24.0      0      2  250649  14.5   NaN        S
#
#
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 441          442         0       3  Hampe, Mr. Leon  male  20.0      0      0
#
#      Ticket  Fare Cabin Embarked
# 441  345769   9.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 296          297         0       3  Hanna, Mr. Mansour  male  23.5      0
#
#      Parch Ticket    Fare Cabin Embarked
# 296      0   2693  7.2292   NaN        C
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 860          861         0       3  Hansen, Mr. Claus Peter  male  41.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 860      2      0  350026  14.1083   NaN        S
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 704          705         0       3  Hansen, Mr. Henrik Juul  male  26.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 704      1      0  350025  7.8542   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 623          624         0       3  Hansen, Mr. Henry Damsgaard  male  21.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 623      0      0  350029  7.8542   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 370          371         1       1  Harder, Mr. George Achilles  male  25.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 370      1      0  11765  55.4417   E50        C
#
#
#      PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 235          236         0       3  Harknett, Miss. Alice Phoebe  female  NaN
#
#      SibSp  Parch      Ticket  Fare Cabin Embarked
# 235      0      0  W./C. 6609  7.55   NaN        S
#
#
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 785          786         0       3  Harmer, Mr. Abraham (David Lishin)  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 785  25.0      0      0  374887  7.25   NaN        S
#
#
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 720          721         1       2  Harper, Miss. Annie Jessie "Nina"  female
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 720  6.0      0      1  248727  33.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 645          646         1       1  Harper, Mr. Henry Sleeper  male  48.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 645      1      0  PC 17572  76.7292   D33        C
#
#
#     PassengerId  Survived  Pclass                                      Name  \
# 52           53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
#
#        Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 52  female  49.0      1      0  PC 17572  76.7292   D33        C
#
#
#      PassengerId  Survived  Pclass               Name   Sex   Age  SibSp  \
# 848          849         0       2  Harper, Rev. John  male  28.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 848      1  248727  33.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex  Age  \
# 602          603         0       1  Harrington, Mr. Charles H  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 602      0      0  113796  42.4   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 570          571         1       2  Harris, Mr. George  male  62.0      0
#
#      Parch       Ticket  Fare Cabin Embarked
# 570      0  S.W./PP 752  10.5   NaN        S
#
#
#     PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 62           63         0       1  Harris, Mr. Henry Birkhardt  male  45.0
#
#     SibSp  Parch Ticket    Fare Cabin Embarked
# 62      1      0  36973  83.475   C83        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 219          220         0       2  Harris, Mr. Walter  male  30.0      0
#
#      Parch     Ticket  Fare Cabin Embarked
# 219      0  W/C 14208  10.5   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 230          231         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 230  Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1      0
#
#     Ticket    Fare Cabin Embarked
# 230  36973  83.475   C83        S
#
#
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 263          264         0       1  Harrison, Mr. William  male  40.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 263      0  112059   0.0   B94        S
#
#
#      PassengerId  Survived  Pclass                    Name     Sex  Age  \
# 535          536         1       2  Hart, Miss. Eva Miriam  female  7.0
#
#      SibSp  Parch        Ticket   Fare Cabin Embarked
# 535      0      2  F.C.C. 13529  26.25   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 314          315         0       2  Hart, Mr. Benjamin  male  43.0      1
#
#      Parch        Ticket   Fare Cabin Embarked
# 314      1  F.C.C. 13529  26.25   NaN        S
#
#
#      PassengerId  Survived  Pclass             Name   Sex  Age  SibSp  Parch  \
# 411          412         0       3  Hart, Mr. Henry  male  NaN      0      0
#
#      Ticket    Fare Cabin Embarked
# 411  394140  6.8583   NaN        Q
#
#
#      PassengerId  Survived  Pclass  \
# 440          441         1       2
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 440  Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female  45.0      1      1
#
#            Ticket   Fare Cabin Embarked
# 440  F.C.C. 13529  26.25   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 681          682         1       1  Hassab, Mr. Hammad  male  27.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 681      0  PC 17572  76.7292   D49        C
#
#
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 731          732         0       3  Hassan, Mr. Houssein G N  male  11.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 731      0      0   2699  18.7875   NaN        C
#
#
#      PassengerId  Survived  Pclass                         Name   Sex  Age  \
# 740          741         1       1  Hawksford, Mr. Walter James  male  NaN
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 740      0      0  16988  30.0   D45        S
#
#
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 310          311         1       1  Hays, Miss. Margaret Bechstein  female
#
#       Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 310  24.0      0      0  11767  83.1583   C54        C
#
#
#      PassengerId  Survived  Pclass  \
# 820          821         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 820      1  12749  93.5   B69        S
#
#
#      PassengerId  Survived  Pclass                        Name     Sex  Age  \
# 274          275         1       3  Healy, Miss. Hanora "Nora"  female  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 274      0      0  370375  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 804          805         1       3  Hedman, Mr. Oskar Arvid  male  27.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 804      0      0  347089  6.975   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 654          655         0       3  Hegarty, Miss. Hanora "Nora"  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 654  18.0      0      0  365226  6.75   NaN        Q
#
#
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 816          817         0       3  Heininen, Miss. Wendla Maria  female
#
#       Age  SibSp  Parch            Ticket   Fare Cabin Embarked
# 816  23.0      0      0  STON/O2. 3101290  7.925   NaN        S
#
#
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 313          314         0       3  Hendekovic, Mr. Ignjac  male  28.0      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 313      0  349243  7.8958   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name     Sex  Age  SibSp  \
# 264          265         0       3  Henry, Miss. Delia  female  NaN      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 264      0  382649  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 615          616         1       2  Herman, Miss. Alice  female  24.0      1
#
#      Parch  Ticket  Fare Cabin Embarked
# 615      2  220845  65.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 754          755         1       2  Herman, Mrs. Samuel (Jane Laver)  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 754  48.0      1      2  220845  65.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 15  55.0      0      0  248706  16.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 655          656         0       2  Hickman, Mr. Leonard Mark  male  24.0
#
#      SibSp  Parch        Ticket  Fare Cabin Embarked
# 655      2      0  S.O.C. 14879  73.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 665          666         0       2  Hickman, Mr. Lewis  male  32.0      2
#
#      Parch        Ticket  Fare Cabin Embarked
# 665      0  S.O.C. 14879  73.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 120          121         0       2  Hickman, Mr. Stanley George  male  21.0
#
#      SibSp  Parch        Ticket  Fare Cabin Embarked
# 120      2      0  S.O.C. 14879  73.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 329          330         1       1  Hippach, Miss. Jean Gertrude  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 329  16.0      0      1  111361  57.9792   B18        C
#
#
#      PassengerId  Survived  Pclass  \
# 523          524         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 523  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 523      1  111361  57.9792   B18        C
#
#
#      PassengerId  Survived  Pclass                      Name     Sex  Age  \
# 479          480         1       3  Hirvonen, Miss. Hildur E  female  2.0
#
#      SibSp  Parch   Ticket     Fare Cabin Embarked
# 479      0      1  3101298  12.2875   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 529          530         0       2  Hocking, Mr. Richard George  male  23.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 529      2      1  29104  11.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                                   Name  \
# 774          775         1       2  Hocking, Mrs. Elizabeth (Eliza Needs)
#
#         Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 774  female  54.0      1      3  29105  23.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 723          724         0       2  Hodges, Mr. Henry Price  male  50.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 723      0      0  250643  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                                  Name  \
# 765          766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
#
#         Sex   Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 765  female  51.0      1      0  13502  77.9583   D11        S
#
#
#      PassengerId  Survived  Pclass               Name   Sex   Age  SibSp  \
# 236          237         0       2  Hold, Mr. Stephen  male  44.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 236      0  26707  26.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 818          819         0       3  Holm, Mr. John Fredrik Alexander  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 818  43.0      0      0  C 7075  6.45   NaN        S
#
#
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 35           36         0       1  Holverson, Mr. Alexander Oskar  male  42.0
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 35      1      0  113789  52.0   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 383          384         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
#
#      Parch  Ticket  Fare Cabin Embarked
# 383      0  113789  52.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 604          605         1       1  Homer, Mr. Harry ("Mr E Haven")  male
#
#       Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 604  35.0      0      0  111426  26.55   NaN        C
#
#
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 216          217         1       3  Honkanen, Miss. Eliina  female  27.0
#
#      SibSp  Parch            Ticket   Fare Cabin Embarked
# 216      0      0  STON/O2. 3101283  7.925   NaN        S
#
#
#     PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 72           73         0       2  Hood, Mr. Ambrose Jr  male  21.0      0
#
#     Parch        Ticket  Fare Cabin Embarked
# 72      0  S.O.C. 14879  73.5   NaN        S
#
#
#      PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 613          614         0       3  Horgan, Mr. John  male  NaN      0      0
#
#      Ticket  Fare Cabin Embarked
# 613  370377  7.75   NaN        Q
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 288          289         1       2  Hosono, Mr. Masabumi  male  42.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 288      0  237798  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 224          225         1       1  Hoyt, Mr. Frederick Maxfield  male  38.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 224      1      0  19943  90.0   C93        S
#
#
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 793          794         0       1  Hoyt, Mr. William Fisher  male  NaN
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 793      0      0  PC 17600  30.6958   NaN        C
#
#
#      PassengerId  Survived  Pclass  \
# 486          487         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 486  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 486      0  19943  90.0   C93        S
#
#
#      PassengerId  Survived  Pclass                                      Name  \
# 699          700         0       3  Humblen, Mr. Adolf Mathias Nicolai Olsen
#
# ...
#
#
#      PassengerId  Survived  Pclass  \
# 799          800         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
#
#      Parch  Ticket   Fare Cabin Embarked
# 799      1  345773  24.15   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 170          171         0       1  Van der hoef, Mr. Wyckoff  male  61.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 170      0      0  111240  33.5   B19        S
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 752          753         0       3  Vande Velde, Mr. Johannes Joseph  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 752  33.0      0      0  345780   9.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 200          201         0       3  Vande Walle, Mr. Nestor Cyriel  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 200  28.0      0      0  345770   9.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 355          356         0       3  Vanden Steen, Mr. Leo Peter  male  28.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 355      0      0  345783   9.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 873          874         0       3  Vander Cruyssen, Mr. Victor  male  47.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 873      0      0  345765   9.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 38           39         0       3  Vander Planke, Miss. Augusta Maria  female
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 38  18.0      2      0  345764  18.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 333          334         0       3  Vander Planke, Mr. Leo Edmondus  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 333  16.0      2      0  345764  18.0   NaN        S
#
#
#     PassengerId  Survived  Pclass  \
# 18           19         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
#
#     Parch  Ticket  Fare Cabin Embarked
# 18      0  345763  18.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                                  Name  \
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 14  female  14.0      0      0  350406  7.8542   NaN        S
#
#
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 521          522         0       3  Vovk, Mr. Janko  male  22.0      0      0
#
#      Ticket    Fare Cabin Embarked
# 521  349252  7.8958   NaN        S
#
#
#     PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 80           81         0       3  Waelens, Mr. Achille  male  22.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 80      0  345767   9.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 515          516         0       1  Walker, Mr. William Anderson  male  47.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 515      0      0  36967  34.0208   D46        S
#
#
#      PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 258          259         1       1  Ward, Miss. Anna  female  35.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 258      0  PC 17755  512.3292   NaN        C
#
#
#      PassengerId  Survived  Pclass  \
# 366          367         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
#
#      Parch  Ticket   Fare Cabin Embarked
# 366      0  110813  75.25   D37        C
#
#
#      PassengerId  Survived  Pclass                        Name   Sex  Age  \
# 674          675         0       2  Watson, Mr. Ennis Hastings  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 674      0      0  239856   0.0   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 161          162         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 161  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0      0
#
#      Parch      Ticket   Fare Cabin Embarked
# 161      0  C.A. 33595  15.75   NaN        S
#
#
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 123          124         1       2  Webber, Miss. Susan  female  32.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 123      0  27267  13.0  E101        S
#
#
#      PassengerId  Survived  Pclass               Name   Sex  Age  SibSp  \
# 511          512         0       3  Webber, Mr. James  male  NaN      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 511      0  SOTON/OQ 3101316  8.05   NaN        S
#
#
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 694          695         0       1  Weir, Col. John  male  60.0      0      0
#
#      Ticket   Fare Cabin Embarked
# 694  113800  26.55   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 133          134         1       2
#
#                                               Name     Sex   Age  SibSp  \
# 133  Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0      1
#
#      Parch  Ticket  Fare Cabin Embarked
# 133      0  228414  26.0   NaN        S
#
#
#      PassengerId  Survived  Pclass               Name     Sex  Age  SibSp  \
# 750          751         1       2  Wells, Miss. Joan  female  4.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 750      1  29103  23.0   NaN        S
#
#
#     PassengerId  Survived  Pclass                          Name     Sex  Age  \
# 58           59         1       2  West, Miss. Constance Mirium  female  5.0
#
#     SibSp  Parch      Ticket   Fare Cabin Embarked
# 58      1      2  C.A. 34651  27.75   NaN        S
#
#
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 450          451         0       2  West, Mr. Edwy Arthur  male  36.0      1
#
#      Parch      Ticket   Fare Cabin Embarked
# 450      2  C.A. 34651  27.75   NaN        S
#
#
#      PassengerId  Survived  Pclass                                     Name  \
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 472  female  33.0      1      2  C.A. 34651  27.75   NaN        S
#
#
#     PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 33           34         0       2  Wheadon, Mr. Edward H  male  66.0      0
#
#     Parch      Ticket  Fare Cabin Embarked
# 33      0  C.A. 24579  10.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 124          125         0       1  White, Mr. Percival Wayland  male  54.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 124      0      1  35281  77.2875   D26        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 102          103         0       1  White, Mr. Richard Frasar  male  21.0
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 102      0      1  35281  77.2875   D26        S
#
#
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 318          319         1       1  Wick, Miss. Mary Natalie  female  31.0
#
#      SibSp  Parch Ticket      Fare Cabin Embarked
# 318      0      2  36928  164.8667    C7        S
#
#
#      PassengerId  Survived  Pclass  \
# 856          857         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 856  Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1      1
#
#     Ticket      Fare Cabin Embarked
# 856  36928  164.8667   NaN        S
#
#
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 406          407         0       3  Widegren, Mr. Carl/Charles Peter  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 406  51.0      0      0  347064  7.75   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 377          378         0       1  Widener, Mr. Harry Elkins  male  27.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 377      0      2  113503  211.5   C82        C
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 371          372         0       3  Wiklund, Mr. Jakob Alfred  male  18.0
#
#      SibSp  Parch   Ticket    Fare Cabin Embarked
# 371      1      0  3101267  6.4958   NaN        S
#
#
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 673          674         1       2  Wilhelms, Mr. Charles  male  31.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 673      0  244270  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 648          649         0       3  Willey, Mr. Edward  male  NaN      0
#
#      Parch         Ticket  Fare Cabin Embarked
# 648      0  S.O./P.P. 751  7.55   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 155          156         0       1  Williams, Mr. Charles Duane  male  51.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 155      0      1  PC 17597  61.3792   NaN        C
#
#
#     PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 17           18         1       2  Williams, Mr. Charles Eugene  male  NaN
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 17      0      0  244373  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 304          305         0       3  Williams, Mr. Howard Hugh "Harry"  male
#
#      Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# 304  NaN      0      0  A/5 2466  8.05   NaN        S
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 735          736         0       3  Williams, Mr. Leslie  male  28.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 735      0  54636  16.1   NaN        S
#
#
#      PassengerId  Survived  Pclass                                    Name  \
# 351          352         0       1  Williams-Lambert, Mr. Fletcher Fellows
#
#       Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 351  male  NaN      0      0  113510  35.0  C128        S
#
#
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 491          492         0       3  Windelov, Mr. Einar  male  21.0      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 491      0  SOTON/OQ 3101317  7.25   NaN        S
#
#
#      PassengerId  Survived  Pclass                    Name   Sex  Age  SibSp  \
# 425          426         0       3  Wiseman, Mr. Phillippe  male  NaN      0
#
#      Parch      Ticket  Fare Cabin Embarked
# 425      0  A/4. 34244  7.25   NaN        S
#
#
#     PassengerId  Survived  Pclass               Name   Sex  Age  SibSp  Parch  \
# 55           56         1       1  Woolner, Mr. Hugh  male  NaN      0      0
#
#    Ticket  Fare Cabin Embarked
# 55  19947  35.5   C52        S
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 555          556         0       1  Wright, Mr. George  male  62.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 555      0  113807  26.55   NaN        S
#
#
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 620          621         0       3  Yasbeck, Mr. Antoni  male  27.0      1
#
#      Parch Ticket     Fare Cabin Embarked
# 620      0   2659  14.4542   NaN        C
#
#
#      PassengerId  Survived  Pclass                                     Name  \
# 830          831         1       3  Yasbeck, Mrs. Antoni (Selini Alexander)
#
#         Sex   Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 830  female  15.0      1      0   2659  14.4542   NaN        C
#
#
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 325          326         1       1  Young, Miss. Marie Grice  female  36.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked
# 325      0      0  PC 17760  135.6333   C32        C
#
#
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 203          204         0       3  Youseff, Mr. Gerious  male  45.5      0
#
#      Parch Ticket   Fare Cabin Embarked
# 203      0   2628  7.225   NaN        C
#
#
#      PassengerId  Survived  Pclass               Name   Sex  Age  SibSp  \
# 354          355         0       3  Yousif, Mr. Wazli  male  NaN      0
#
#      Parch Ticket   Fare Cabin Embarked
# 354      0   2647  7.225   NaN        C
#
#
#      PassengerId  Survived  Pclass                   Name   Sex  Age  SibSp  \
# 495          496         0       3  Yousseff, Mr. Gerious  male  NaN      0
#
#      Parch Ticket     Fare Cabin Embarked
# 495      0   2627  14.4583   NaN        C
#
#
#      PassengerId  Survived  Pclass                                    Name  \
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 199  female  24.0      0      0  248747  13.0   NaN        S
#
#
#      PassengerId  Survived  Pclass                  Name     Sex   Age  SibSp  \
# 111          112         0       3  Zabour, Miss. Hileni  female  14.5      1
#
#      Parch Ticket     Fare Cabin Embarked
# 111      0   2665  14.4542   NaN        C
#
#
#      PassengerId  Survived  Pclass                   Name     Sex  Age  SibSp  \
# 240          241         0       3  Zabour, Miss. Thamine  female  NaN      1
#
#      Parch Ticket     Fare Cabin Embarked
# 240      0   2665  14.4542   NaN        C
#
#
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 422          423         0       3  Zimmerman, Mr. Leo  male  29.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 422      0  315082  7.875   NaN        S
#
#
#      PassengerId  Survived  Pclass  \
# 559          560         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 559  de Messemaeker, Mrs. Guillaume Joseph (Emma)  female  36.0      1      0
#
#      Ticket  Fare Cabin Embarked
# 559  345572  17.4   NaN        S
#
#
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 286          287         1       3  de Mulder, Mr. Theodore  male  30.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 286      0      0  345774   9.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 282          283         0       3  de Pelsmaeker, Mr. Alfons  male  16.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 282      0      0  345778   9.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 361          362         0       2  del Carlo, Mr. Sebastiano  male  29.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked
# 361      1      0  SC/PARIS 2167  27.7208   NaN        C
#
#
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
#
#       Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# 153  40.5      0      2  A/5. 851  14.5   NaN        S
#
#
#      PassengerId  Survived  Pclass                         Name   Sex  Age  \
# 868          869         0       3  van Melkebeke, Mr. Philemon  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 868      0      0  345777   9.5   NaN        S

# %%
import pandas as pd
df = pd.read_csv('/scraped_data.csv')

# %%
df.isna().sum()
# Out:
# Country        0
# 2005 Sales     1
# 2006 Sales     1
# 2007 Sales     1
# 2008 Sales     1
# 2009 Sales     1
# 2010 Sales     1
# 2011 Sales     1
# 2012 Sales     1
# 2013 Sales     1
# 2014 Sales     1
# 2015 Sales     0
# 2016 Sales     3
# 2017 Sales     1
# 2018 Sales     1
# 2019 Sales     1
# 2020 Sales    84
# 2021 Sales    83
# 2022 Sales    84
# dtype: int64

# %%
df.tail(20)
# Out:
#           Country 2005 Sales 2006 Sales 2007 Sales 2008 Sales 2009 Sales  \
# 121         Qatar     61,100     59,900     60,500     60,000     40,000
# 122   R. of Congo        200        200        200        500      1,500
# 123       Senegal      3,000      3,000      3,000      3,000      4,000
# 124        Serbia     21,603     25,610     32,772     36,177     30,000
# 125     Singapore    109,167    116,849    110,814    100,979     73,183
# 126      Slovenia     59,324     59,578     68,719     71,575     57,967
# 127     Sri Lanka      2,600      2,800      2,900      3,000      3,000
# 128         Sudan      2,000      2,000      2,500      3,000      7,000
# 129         Syria     32,985     45,467     36,000     42,000     46,000
# 130    Tajikistan      5,300      5,700      5,800      6,000      7,000
# 131      Tanzania      2,000      2,000      2,000      2,000      2,000
# 132    Tr.&Tobago     10,000     10,000      5,000     10,000     10,000
# 133       Tunisia     25,000     30,000     30,000     33,000     35,000
# 134  Turkmenistan      3,900      4,200      4,300      4,500      4,500
# 135        Uganda      3,000      3,500      3,000      3,000      3,000
# 136       Uruguay     10,000     10,000     12,000     15,000     30,000
# 137     Venezuela    128,601    184,108    267,932    135,882     67,047
# 138         Yemen      4,000      4,700      4,800      5,000      5,000
# 139        Zambia      2,300      2,700      2,800      2,600      3,000
# 140      Zimbabwe      7,000      6,000      3,000      3,000      3,000
#
#     2010 Sales 2011 Sales 2012 Sales 2013 Sales 2014 Sales 2015 Sales  \
# 121     40,000     45,000     60,000     65,000     71,500     69,200
# 122      1,500      1,500      1,500      1,500      1,500      1,600
# 123      4,000      3,500      4,000      4,000      4,500      3,700
# 124     28,951     22,181     22,800     23,000     23,900     21,700
# 125     47,273     33,493     32,724     27,955     32,807     61,512
# 126     61,142     60,193     50,091     52,268     53,296     59,450
# 127      2,000      7,000      8,000     10,000     13,800     12,500
# 128      2,000      2,000      2,000      1,500      1,800      2,200
# 129     78,147     33,160     36,300     35,500     33,400     33,400
# 130      6,500      7,500      6,000      6,000      6,100      6,100
# 131      2,000      3,000      3,000      3,500      1,000      2,600
# 132     10,000     10,000      8,000      8,000      6,300     10,500
# 133     45,000     35,000     37,000     35,000     37,100     36,100
# 134      4,500      5,000      4,500      4,500      4,600      4,600
# 135      3,000      3,000      3,000      3,000      3,000      2,200
# 136     40,000     38,308     38,109     41,785     40,171     39,472
# 137     68,210     65,339     60,776     43,887     10,400      7,700
# 138      2,000      2,000      2,000      2,000      2,500      2,300
# 139      2,000      2,000      2,000      2,000      2,000      1,700
# 140      2,000      3,000      3,000      3,000      4,100      1,500
#
#     2016 Sales 2017 Sales 2018 Sales 2019 Sales 2020 Sales 2021 Sales  \
# 121     50,200     41,176     38,816     39,679        NaN        NaN
# 122        NaN        NaN        NaN        NaN        NaN        NaN
# 123      4,400      3,773      3,558      3,320        NaN        NaN
# 124     23,300     22,090     24,006     25,514        NaN        NaN
# 125     91,096     94,692     81,625     76,476        NaN        NaN
# 126     63,674     62,522     65,115     70,904        NaN        NaN
# 127     26,300     11,796     10,981      8,100        NaN        NaN
# 128        NaN      1,450      1,140        996        NaN        NaN
# 129     33,400      4,500      6,996     11,428        NaN        NaN
# 130      1,900      2,000      2,200      2,200        NaN        NaN
# 131      2,300        938        998        675        NaN        NaN
# 132     13,900      9,840      9,712     10,707        NaN        NaN
# 133     36,400     45,886     35,343     34,387        NaN        NaN
# 134      4,500      4,800      5,100      5,225        NaN        NaN
# 135      2,900        721        770        832        NaN        NaN
# 136     35,924     41,549     34,377     30,063        NaN        NaN
# 137      3,200      2,500      1,159      3,000        NaN        NaN
# 138      1,100        828        552        552        NaN        NaN
# 139      2,300        848      1,118      1,094        NaN        NaN
# 140      1,300      1,094        906        532        NaN        NaN
#
#     2022 Sales
# 121        NaN
# 122        NaN
# 123        NaN
# 124        NaN
# 125        NaN
# 126        NaN
# 127        NaN
# 128        NaN
# 129        NaN
# 130        NaN
# 131        NaN
# 132        NaN
# 133        NaN
# 134        NaN
# 135        NaN
# 136        NaN
# 137        NaN
# 138        NaN
# 139        NaN
# 140        NaN

# %%
merged_df=pd.merge(df.head(2),df.tail(2),how='outer',indicator=True)
merged_df
# Out:
#     Country 2005 Sales 2006 Sales 2007 Sales 2008 Sales  2009 Sales  \
# 0     China  3,971,101  5,175,961  6,297,538  6,755,609  10,331,315
# 1     India  1,106,863  1,311,373  1,511,812  1,545,414   1,816,878
# 2    Zambia      2,300      2,700      2,800      2,600       3,000
# 3  Zimbabwe      7,000      6,000      3,000      3,000       3,000
#
#    2010 Sales  2011 Sales  2012 Sales  2013 Sales  2014 Sales  2015 Sales  \
# 0  13,757,794  14,472,416  15,495,240  17,927,730  19,707,677  21,210,339
# 1   2,387,197   2,510,313   2,781,919   2,553,979   2,570,736   2,772,270
# 2       2,000       2,000       2,000       2,000       2,000       1,700
# 3       2,000       3,000       3,000       3,000       4,100       1,500
#
#    2016 Sales  2017 Sales  2018 Sales  2019 Sales  2020 Sales  2021 Sales  \
# 0  24,376,902  24,718,321  23,709,782  21,472,092  20,177,731  21,481,537
# 1   2,966,637   3,229,109   3,394,756   2,962,115   2,433,464   3,082,279
# 2       2,300         848       1,118       1,094         NaN         NaN
# 3       1,300       1,094         906         532         NaN         NaN
#
#    2022 Sales      _merge
# 0  23,563,287   left_only
# 1   3,792,356   left_only
# 2         NaN  right_only
# 3         NaN  right_only
